# %%
from copy import deepcopy
from collections import defaultdict
import random
import numpy as np
import time 
import json
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %% [markdown]
# ## Reading and initializing functions

# %%
def get_sudokus(filename, sudokusize=9):
    '''
    get_states is to read multiple sudokus in the format:
    ..8..4..5...64..5 etc.
    returns a list of sudoku board states as clauses in a dict
    '''
    sudokus = []
    with open(filename) as sudoku_states:
        for i, state in enumerate(sudoku_states):
            sudoku = {}
            pointers = {}
            row = 1
            index = 0
            for j, content in enumerate(state):
                if j%sudokusize == 0 and j > 0:
                    row+=1
                try:
                    int(content)
                    literal = int(str(row) + str(j%sudokusize+1) + content)
                    sudoku[index] = [literal]
                    if literal not in pointers.keys():
                        pointers[literal] = [index]
                    else:
                        pointers[literal].append(index)
                    index += 1
                except:
                    # is not convertible to int
                    continue
            sudokus.append((sudoku, pointers))
    return sudokus

def get_constraints_from_dimacs(filename, prevConstraints={}, prevPointers={}):
    '''
    Convert dimacs file to a dictionary of constraints
    and pointers. Allows merging with previous pointers and constraints.
    '''
    constraints = prevConstraints # dictionary with constraints as: clausenumber->[literals]
    pointers = prevPointers # dictionary with pointers to clause numbers for literals as: literals->[clausenumbers]
    initial_length = len(constraints)
    with open(filename) as f:
        for i, clause in enumerate(f):
            index = i + initial_length
            if clause[0] == 'c' or clause[0] == 'p':
                # skip comments etc.
                continue
            constraints[index]= []
            for literal in clause.split():
                literal = int(literal)
                if literal != 0:
                    constraints[index].append(literal)
                    if literal not in pointers.keys():
                        pointers[literal] = [index]
                    else:
                        pointers[literal].append(index)
                    
    return constraints, pointers

# %% [markdown]
# ## DP helper functions for constraints updates

# %%
def assign_literal(constraints, pointers, literal, assignments):
    '''
    assign the given literal to be True.
    assign_literal is aimed to be one recursion stack, so deepcopies are made
    in order to properly backtrack
    '''
    constraintsCopied = deepcopy(constraints)
    pointersCopied = deepcopy(pointers)
    assignmentsCopied = deepcopy(assignments)
    assignmentsUpdated = update_assigments(assignmentsCopied, literal)
    constraintsUpdated, pointersUpdated = update_constraints(constraintsCopied, pointersCopied, literal)
    return constraintsUpdated, pointersUpdated, assignmentsUpdated
     
def update_constraints(constraints, pointers, literal):
    '''
    literal: e.g. 112 or 112'
    Updates constraints and pointers by removing all clauses 
    with the given literal, because the clause becomes true.
    Remove counter-literal out of all clauses.
    '''
    ## Find clauses with literal and remove them
    
    for lit in literal:
        clauses=list(pointers[lit])
        for clause in clauses:
            for l in constraints[clause]:
                pointers[l].remove(clause)
                if len(pointers[l])==0 and l!=lit:
                    del pointers[l]
            del constraints[clause]
        del pointers[lit]
    
    ## Find clauses with counter-literal and remove its counter-literal
    
    for lit in literal:
        counterLiteral = -lit
        if counterLiteral in pointers.keys():
            counters=list(pointers[counterLiteral])
            for clause in counters:
                constraints[clause].remove(counterLiteral)
            del pointers[counterLiteral]
        else:
            continue
   
    return constraints, pointers

def update_assigments(assignments, literal):
    '''
    Keep track of assigned literals.
    Needed in order to return satisfiable solution of literals.
    '''
    for lit in literal:
        if lit in assignments:
            print("already assigned", lit, "(in this stack), returning...")
#             return
        else:
            assignments.append(lit)
    return assignments

def check_tautologies(constraints, pointers):
    '''
    Check for clauses with a tautology and remove
    them.
    '''
    foundOne = False
    for clause in constraints.keys():
        literals = constraints[clause]
        counterLiterals = [-x for x in literals]
        for i in literals:
            for j in counterLiterals:
                if i == j:
                    del constraints[clause]
                    pointers[i].remove(clause)
                    pointers[-i].remove(clause)
                    foundOne = True
                    break
    if foundOne:
        print("Found tautologies and removed corresponding clauses")
    else:
        print("No tautologies found")
                  
    return constraints, pointers

# %% [markdown]
# ### Extract features to use as regressor datapoints

# %%
def extract_features(literals, constraints, pointers, assignments, logging=True):
    
    literal = next(iter(literals))
    ## Look one step ahead
    constraintsNew, pointersNew, assignmentsNew = assign_literal(constraints, pointers, literals, assignments)
    
    ## Ratio of the polarity of this literal before assignment
    positive = len(pointers[literal])
    negative = len(pointers[-literal])
    total = positive+negative
    if total != 0:
        ratio = positive/(positive+negative)
    else:
        ratio = 0
    
    # Clauses that were resolved with this assignment
    clausesResolved = len(constraints) - len(constraintsNew)
    
    # Clauses that became empty with this assignment
    emptyClauses = 0
    for clause in constraintsNew.keys():
        if not constraintsNew[clause]:
            emptyClauses += 1
    
    ## Average clause length with given literal before assignment
    clauses = pointers[literal]
    lengths = [len(constraints[c]) for c in clauses]
    if len(lengths) != 0:
        mean = np.mean(lengths) 
    else:
        mean = 0
        
    _, momScores = mom(constraints, pointers, 1, [literal])
    
    _, jerowScores = jeroSloWang(constraints, pointers, [literal])
    
    if logging:
        global features
        features[literal] = {}
        features[literal]["posneg_ratio"] = ratio
        features[literal]["c_res"] = clausesResolved
        features[literal]["empty_c"] = emptyClauses  
        features[literal]["c_len"] = mean
        features[literal]["SAT"] = 0
        features[literal]["mom"] = next(iter(momScores))
        features[literal]["jerow"] = next(iter(jerowScores))
    else:
        norma=norm([ratio, clausesResolved, emptyClauses, mean, next(iter(momScores)), next(iter(jerowScores))])
        return norma
def norm(X):
    newX=[]
#     print(len(X),len(X[0]))
#     print(X)
#     print(maxmin['posneg_ratio'][1],maxmin['posneg_ratio'][0])
    newX.append((X[0]-maxmin['posneg_ratio'][1])/(maxmin['posneg_ratio'][0]-maxmin['posneg_ratio'][1]))
    newX.append((X[1]-maxmin['c_res'][1])/(maxmin['c_res'][0]-maxmin['c_res'][1]))
    newX.append(X[2])
    newX.append((X[3]-maxmin['c_len'][1])/(maxmin['c_len'][0]-maxmin['c_len'][1]))
    newX.append((X[4]-maxmin['mom'][1])/(maxmin['mom'][0]-maxmin['mom'][1]))
    newX.append((X[5]-maxmin['jerow'][1])/(maxmin['jerow'][0]-maxmin['jerow'][1]))
#     print(newX)
    return newX

# %%
maxmin
# Out:
# {'SAT': (1, 0),
#  'c_len': (6.75, 2.0),
#  'c_res': (23, 4),
#  'empty_c': (0, 0),
#  'jerow': (5.75, 0.04296875),
#  'mom': (48, 0),
#  'posneg_ratio': (0.8518518518518511, 0.148148148148148)}

# %% [markdown]
# ### Train linear discriminant

# %%
def train(file=None):
    X = []
    y = []
    with open(file) as f:  
        data = json.load(f)
        for d in data:
            row = list(d.values())
            x = row[:]
            x.pop(-3)
            X.append(x)
            y.append(row[-3])
    global regressor
    regressor = LogisticRegression().fit(np.array(X), np.array(y))

# %% [markdown]
# ## DP cases

# %%
def empty_clause(constraints):
    for clause in constraints.keys():
        if not constraints[clause]:
            return True
        
    return False

def unit_clause(constraints): 
    units=[]
    negUnit=[]
    for clause in constraints.keys():
        if len(constraints[clause])==1:
            literal = constraints[clause][0]
            if literal>0:
                units.append(literal)
            else:
                negUnit.append(literal)
    if len(units)>0:
        return list(set(units))
    else:
        return list(set(negUnit))

def unit_propagate(constraints, pointers, assignments):
    '''
    Automatically assign the literal of all unit clauses
    until there are no unit clauses left.
    '''
    literals = unit_clause(constraints)
    if len(literals)>0:
        status=True
        constraints, pointers, assignments = assign_literal(constraints, pointers, literals, assignments)    
    else:
        status=False
    
    return constraints, pointers, assignments,status

def pure_literal(pointers):
    literals=list(pointers.keys())
    for literal in literals:
        if -literal not in literals:
            return [literal],True
        
    return None,False

def random_literal(pointers):
    literals=list(pointers.keys())  
    try:
        literal = random.choice(literals) 
    except:
        return []
    
    return [literal]

# %% [markdown]
# ### Branch split heuristics

# %%
def logreg(constraints, pointers, assignments, b=5): 
    '''
    Logreg performs a prediction on a batch of literals and picks the highest scoring literal.
    '''
    if(len(pointers.keys()) < b):
        b = len(pointers.keys())
    if len(pointers.keys())==0:
        return []
    batch = random.sample(list(pointers.keys()), k=b)
    X = np.array([extract_features([literal], constraints, pointers, assignments, logging=False) for literal in batch])
    scores = regressor.predict(X) # globally available regressor
    literal = batch[np.argmax(scores)]
    return [literal]
    
#Mom's heuristic    
def mom(constraints, pointers, k, batch=False):
    momScores = []
    smallestClasses=[]
    minClass=np.inf
    for clause in constraints.keys():
        if len(constraints[clause])<minClass:
            minClass=len(constraints[clause])
            smallestClasses=[]
            smallestClasses.append(clause)
        elif len(constraints[clause])==minClass:
            smallestClasses.append(clause)
    value=0
    maxLiteral=None
    haveSeen=[]
    
    if batch:
        b = batch
    else:
        b = pointers.keys()
    
    for literal in b:
        if literal not in haveSeen and -literal not in haveSeen:
            X=len([x for x in pointers[literal] if x in smallestClasses])
            X_=len([x for x in pointers[-literal] if x in smallestClasses])
            momsValue=(X+X_)*2^k+(X*X_)
            momScores.append(momsValue)
            haveSeen.append(literal)
            if momsValue>value:
                value=momsValue
                maxLiteral=literal
    if maxLiteral:
        return [maxLiteral], momScores
    else:
        return [], momScores
    
#jeroslow wang heuristic
def jeroSloWang(constraints, pointers, batch=False):
    j={}
    jerowScores = []
    maxValue=0
    maxLiteral=None
    if len(pointers.keys())==0:
        return []
    
    if batch:
        b = batch
    else:
        b = pointers.keys()
    
    for literal in b:
        for clause in pointers[literal]:
            if literal not in j.keys():
                j[literal]=0
            j[literal]+=(2**(-len(constraints[clause])))
       
        if j[literal]>maxValue:
            maxValue=j[literal]
            maxLiteral=literal
            
    return [maxLiteral], [j[literal] for literal in batch]

# %% [markdown]
# ## DP main function

# %%
def DP(constraints, pointers, assignments, split): 
    '''
    DP main recursive function. Always returns satisfiable
    assignment for all constraints if there is one.
    '''

    status=True
    while status:
        constraints, pointers, assignments,status = unit_propagate(constraints, pointers, assignments)
        
    status=True
    while status:
        literal,status = pure_literal(pointers)
        if status:
            constraints, pointers, assignments = assign_literal(constraints, pointers, literal, assignments)
    
    if len(constraints.keys())==0:
        return assignments
   
    if empty_clause(constraints):
        return [] 
    
#     batch = random.sample(list(pointers.keys()), 10)
    
    global assignmentCount
    assignmentCount += 1
    if split=="random":
        literal = random_literal(pointers)
        extract_features(literal, constraints, pointers, assignments, logging=True)
        if len(literal)==0:
            return DP(constraints, pointers, assignments, split)
    if split=="jerow":
        literal, scores = jeroSloWang(constraints,pointers)
        if len(literal)==0:
            return DP(constraints, pointers, assignments, split)
    if split=="moms":
        literal, scores = mom(constraints, pointers, 1)
        if len(literal)==0:
            return DP(constraints, pointers, assignments, split)
    if split=="logreg":
        literal = logreg(constraints, pointers, assignments, 5)
        if len(literal)==0:
            return DP(constraints, pointers, assignments, split)
        
    constraintsUpdated, pointersUpdated, assignmentsUpdated = assign_literal(constraints, pointers, literal, assignments)
    assignmentsFinal = DP(constraintsUpdated, pointersUpdated, assignmentsUpdated, split)
    if len(assignmentsFinal)>0:
        return assignmentsFinal
    else:
        constraints, pointers, assignments = assign_literal(constraints, pointers, [literal[0]*-1], assignments)
        return DP(constraints, pointers, assignments,split)

# %% [markdown]
# ### Script

# %%
import pandas as pd

datapoints = []
train_sudokus = [x for x in range(0,1000) if x%2 == 0]
test_sudokus = [x for x in range(0,1000) if x%2 == 1]

print("Training logistic regressor...")
train('new logreg data 1 mrt.json')

run_statistics = {}
df=pd.read_json('new logreg data 1 mrt.json')
maxmin={}
for col in df.keys():
    maxmin[col]=(max(df[col]),min(df[col]))
    
    
sudokus1000 = get_sudokus('1000 sudokus.txt')
# heuristics = ["random", "moms", "jerow", "logreg"]
heuristics = ["logreg"]
    
## Run DP
runs = 1
for run in range(0, runs):
    run_statistics[run] = {}
    for i in test_sudokus:
        run_statistics[run][i] = {}
        for h in heuristics:
            run_statistics[run][i][h] = {}
            ## Get board and rules
            
            print("Reading and analyzing...")
            constraints, pointers = sudokus1000[i]
            run_statistics[run][i][h]["beginAssigments"] = len(pointers)
            constraints, pointers = get_constraints_from_dimacs('sudoku-rules.txt', constraints, pointers)
            constraints, pointers = check_tautologies(constraints, pointers)

            print("Starting DP algorithm with "+ h + " splits...")
            assignmentCount = 0
            global features
            features = {}
            startTime = time.time()
            assignments = DP(constraints, pointers, [], split=h)
            endTime = time.time()
            print("this is number",i,'out of ',len(train_sudokus))
            if assignments:
#                 print("Solution found")
#                 print("Time to complete:", "%2f seconds"%(endTime-startTime))
                boardPositions = [a for a in assignments if a > 0]
#                 print(np.reshape([int(str(pos)[2]) for pos in sorted(boardPositions)], (9,9)))
#                 print("Branch split choices made:", assignmentCount)
                run_statistics[run][i][h]["assignmentCount"] = assignmentCount
                run_statistics[run][i][h]["runTime"] = (endTime-startTime)
                for a in assignments:
                    if a in features.keys():
                        features[a]["SAT"] = 1
                for f in features.keys():
                    datapoints.append(features[f])
            else:
                print("No solution found")
                
if datapoints:                
    with open('new logreg data 1 mrt.json', 'w') as outfile:
        json.dump(datapoints, outfile)

with open('new logreg 1 mrt.json', 'w') as f:
    json.dump(run_statistics, f)
# Out:
# Training logistic regressor...
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 1 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 3 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 5 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 7 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 9 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 11 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 13 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 15 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 17 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 19 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 21 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 23 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 25 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 27 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 29 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 31 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 33 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 35 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 37 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 39 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 41 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 43 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 45 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 47 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 49 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 51 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 53 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 55 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 57 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 59 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 61 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 63 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 65 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 67 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 69 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 71 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 73 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 75 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 77 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 79 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 81 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 83 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 85 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 87 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 89 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 91 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 93 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 95 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 97 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 99 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 101 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 103 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 105 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 107 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 109 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 111 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 113 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 115 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 117 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 119 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 121 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 123 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 125 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 127 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 129 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 131 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 133 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 135 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 137 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 139 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 141 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 143 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 145 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 147 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 149 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 151 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 153 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 155 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 157 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 159 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 161 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 163 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 165 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 167 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 169 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 171 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 173 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 175 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 177 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 179 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 181 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 183 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 185 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 187 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 189 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 191 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 193 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 195 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 197 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 199 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 201 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 203 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 205 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 207 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 209 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 211 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 213 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 215 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 217 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 219 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 221 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 223 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 225 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 227 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 229 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 231 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 233 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 235 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 237 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 239 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 241 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 243 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 245 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 247 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 249 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 251 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 253 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 255 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 257 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 259 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 261 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 263 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 265 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 267 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 269 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 271 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 273 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 275 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 277 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 279 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 281 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 283 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 285 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 287 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 289 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 291 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 293 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 295 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 297 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 299 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 301 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 303 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 305 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 307 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 309 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 311 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 313 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 315 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 317 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 319 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 321 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 323 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 325 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 327 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 329 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 331 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 333 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 335 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 337 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 339 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 341 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 343 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 345 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 347 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 349 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 351 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 353 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 355 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 357 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 359 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 361 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 363 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 365 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 367 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 369 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 371 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 373 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 375 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 377 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 379 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 381 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 383 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 385 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 387 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 389 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 391 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 393 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 395 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 397 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 399 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 401 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 403 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 405 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 407 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 409 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 411 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 413 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 415 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 417 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 419 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 421 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 423 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 425 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 427 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 429 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 431 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 433 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 435 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 437 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 439 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 441 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 443 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 445 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 447 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 449 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 451 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 453 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 455 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 457 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 459 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 461 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 463 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 465 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 467 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 469 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 471 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 473 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 475 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 477 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 479 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 481 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 483 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 485 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 487 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 489 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 491 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 493 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 495 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 497 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 499 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 501 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 503 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 505 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 507 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 509 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 511 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 513 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 515 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 517 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 519 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 521 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 523 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 525 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 527 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 529 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 531 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 533 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 535 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 537 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 539 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 541 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 543 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 545 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 547 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 549 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 551 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 553 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 555 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 557 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 559 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 561 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 563 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 565 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 567 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 569 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 571 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 573 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 575 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 577 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 579 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 581 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 583 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 585 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 587 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 589 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 591 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 593 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 595 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 597 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 599 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 601 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 603 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 605 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 607 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 609 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 611 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 613 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 615 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 617 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 619 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 621 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 623 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 625 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 627 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 629 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 631 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 633 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 635 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 637 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 639 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 641 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 643 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 645 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 647 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 649 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 651 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 653 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 655 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 657 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 659 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 661 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 663 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 665 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 667 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 669 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 671 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 673 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 675 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 677 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 679 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 681 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 683 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 685 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 687 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 689 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 691 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 693 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 695 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 697 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 699 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 701 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 703 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 705 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 707 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 709 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 711 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 713 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 715 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 717 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 719 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 721 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 723 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 725 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 727 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 729 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 731 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 733 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 735 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 737 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 739 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 741 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 743 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 745 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 747 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 749 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 751 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 753 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 755 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 757 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 759 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 761 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 763 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 765 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 767 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 769 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 771 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 773 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 775 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 777 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 779 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 781 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 783 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 785 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 787 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 789 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 791 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 793 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 795 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 797 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 799 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 801 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 803 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 805 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 807 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 809 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 811 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 813 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 815 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 817 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 819 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 821 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 823 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 825 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 827 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 829 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 831 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 833 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 835 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 837 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 839 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 841 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 843 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 845 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 847 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 849 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 851 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 853 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 855 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 857 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 859 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 861 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 863 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 865 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 867 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 869 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 871 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 873 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 875 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 877 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 879 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 881 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 883 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 885 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 887 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 889 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 891 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 893 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 895 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 897 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 899 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 901 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 903 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 905 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 907 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 909 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 911 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 913 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 915 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 917 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 919 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 921 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 923 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 925 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 927 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 929 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 931 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 933 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 935 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 937 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 939 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 941 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 943 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 945 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 947 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 949 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 951 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 953 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 955 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 957 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 959 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 961 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 963 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 965 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 967 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 969 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 971 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 973 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 975 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 977 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 979 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 981 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 983 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 985 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 987 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 989 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 991 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 993 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 995 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 997 out of  500
# Reading and analyzing...
# No tautologies found
# Starting DP algorithm with logreg splits...
# this is number 999 out of  500

# %% [markdown]
# # Optional, load data to train and normalize

# %%
import pandas as pd
df=pd.read_json('new logreg data 1 mrt.json')
df=df[['posneg_ratio','c_res','empty_c','c_len','mom','jerow']]
maxmin={}
for col in df.keys():
    maxmin[col]=(max(df[col]),min(df[col]))
df=df.drop(['empty_c'],axis=1)
for col in df.keys():
    df[col]=df[col].apply(lambda x:(x-maxmin[col][1])/(maxmin[col][0]-maxmin[col][1]))
df.to_json("normalized logreg data 1 mrt.json")

# %% [markdown]
# # Visualizing results

# %%
import pandas as pd
dataTable={}
def analyze_run(file):
    average_time = {}
    average_assignments = {}
    with open(file) as f:
        runs = json.load(f)
        for run in runs.keys():
            for sudoku in runs[run].keys():
                for heuristic in runs[run][sudoku].keys():
                    if heuristic not in average_time.keys():
                        average_time[heuristic] = []
                    if heuristic not in average_assignments.keys():
                        average_assignments[heuristic] = []
                    average_time[heuristic].append(runs[run][sudoku][heuristic]["runTime"])
                    average_assignments[heuristic].append(runs[run][sudoku][heuristic]["assignmentCount"])
    for h in average_time.keys():
        dataTable[file.split('.')[0]+' time']=average_time[h][0:500]
        dataTable[file.split('.')[0]+' assignments']=average_assignments[h][0:500]

analyze_run('output moms.json')
analyze_run('output random.json')
# analyze_run('output log reg.json')
analyze_run('output jerow.json')
# analyze_run('output log not relative.json')
analyze_run('new logreg 1 mrt.json')
df=pd.DataFrame(dataTable)

# %%
num=['i'+str(x) for x in range(len(df))]
df['instance']=num

# %%
df[df['output random assignments']>=0].describe()
# Out:
#        output moms time  output moms assignments  output random time  \
# count        500.000000               500.000000          500.000000
# mean           1.906449                10.584000            0.894273
# std            3.420125                19.794712            1.020970
# min            0.282849                 0.000000            0.180475
# 25%            0.530151                 1.000000            0.410106
# 50%            0.937660                 5.000000            0.566657
# 75%            2.159487                13.000000            0.967610
# max           47.739417               252.000000           10.754009
#
#        output random assignments  output jerow time  output jerow assignments  \
# count                 500.000000         500.000000                500.000000
# mean                    6.614000           6.088390                 14.088000
# std                    10.129275           8.653103                 20.415333
# min                     0.000000           0.905814                  0.000000
# 25%                     1.000000           1.401275                  2.000000
# 50%                     4.000000           2.807046                  7.000000
# 75%                     9.000000           6.709601                 18.000000
# max                   104.000000          59.048210                129.000000
#
#        new logreg 1 mrt time  new logreg 1 mrt assignments
# count             500.000000                    500.000000
# mean                0.753220                      6.650000
# std                 0.847752                      9.133583
# min                 0.167338                      0.000000
# 25%                 0.265733                      1.000000
# 50%                 0.447593                      3.000000
# 75%                 0.817796                      9.000000
# max                 6.287461                     65.000000

# %%
bins={}
for i in range(14):
    if len(bins.keys())==0:
        bins[str(0)+':'+str((i+1)*2)]=df[(df['output random assignments']>=0) & (df['output random assignments']<1*(i+1)*2)]['instance']
    else:
        bins[str(i*2)+':'+str((i+1)*2)]=df[(df['output random assignments']>=2*i) & (df['output random assignments']<1*(i+1)*2)]['instance']

# %%
columns=['output moms assignments',
       'output random assignments', 
       'output jerow assignments',
       'new logreg 1 mrt assignments']

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
fig, ax = plt.subplots(1,figsize=(10, 10))

for col in columns:#['output random assignments']:#columns:
    x=[]
    y=[]
    e=[]
    for bina in bins.keys():
        x.append(bina)
#         print(bina,df[df['instance'].isin(bins[bina])][col])
        y.append(np.mean(df[df['instance'].isin(bins[bina])][col]))
        
        e.append((np.std(df[df['instance'].isin(bins[bina])][col])))
#     plt.plot(x,y,label=col)
# plot it!
    upperbound=[y[i]+e[i] for i in range(len(y))]
    lowerbound=[y[i]-e[i] for i in range(len(y))]
#     print(lowerbound,upperbound)
    ax.plot(x, y, lw=2, label=col)

    ax.set_title("Mean number of assignments compared to random split")
    ax.legend(loc='upper left')
    ax.set_xlabel('mean number of assignments random split')
    ax.set_ylabel('mean number of assignments')
#     ax.grid()    
 
#     plt.legend()
plt.show()

# %%
maxmin
